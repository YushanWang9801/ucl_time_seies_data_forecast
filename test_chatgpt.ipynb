# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.api import ExponentialSmoothing

# Load the DataFrame from the CSV file
df = pd.read_csv('dfmax.csv')

# Fill missing values with NaNs
df[df['temperature'] == -999] = np.nan

# Create the Exponential Smoothing model
model = ExponentialSmoothing(df['temperature'], trend='add', seasonal=None)

# Fit the model and generate forecasts for the missing values
forecast = model.fit().forecast(len(df[df['temperature'].isna()]))

# Replace missing values in the DataFrame with the forecasts
df['temperature'].fillna(pd.Series(forecast, index=df[df['temperature'].isna()].index), inplace=True)

df['temperature'].fillna(pd.Series(forecast, index=df[df['temperature'].isna()].index), inplace=True)
# View the DataFrame with missing values filles
# Out:
# C:\Users\yusha\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.plot(df["temperature"],'.',label='tMax')
